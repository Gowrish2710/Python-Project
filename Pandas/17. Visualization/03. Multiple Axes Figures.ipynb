# %% [markdown]
# # Multiple Axes Figures

# %% [markdown]
# ## Create Multiple Axes with `subplots`
# In previous notebooks, we created a single Axes within a single Figure. In this notebook, we will create multiple Axes within a single Figure. The simplest way to accomplish this is to pass the `subplots` function to create a grid of Axes. Pass it two integers - the number of rows and the number of columns.
#
# Again, two objects are returned from the function. The first is a Figure and the second is a NumPy array of the Axes.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, ax_array = plt.subplots(2, 3, figsize=(8, 4))

# %% [markdown]
# ### Multiple Axes returned as a NumPy array
# Whenever you create multiple Axes on a figure with **`subplots`**, you will be returned a NumPy array of Axes objects. Let's verify that the type and shape of this array.

# %%
type(ax_array)
# Out:
# numpy.ndarray

# %%
ax_array.shape
# Out:
# (2, 3)

# %% [markdown]
# ### Output the array and assign each Axes to a variable
# If we simply output the array, we will see 6 different Axes objects. Let's extract each of these Axes into their own variable.

# %%
ax_array

# %%
ax1 = ax_array[0, 0]
ax2 = ax_array[0, 1]
ax3 = ax_array[0, 2]
ax4 = ax_array[1, 0]
ax5 = ax_array[1, 1]
ax6 = ax_array[1, 2]

# %% [markdown]
# ## Distinguish the Figure from the Axes
# Let's set the face color of the Figure and each of the Axes.

# %%
fig.set_facecolor('red')
ax1.set_facecolor('orange')
ax2.set_facecolor('yellow')
ax3.set_facecolor('green')
ax4.set_facecolor('blue')
ax5.set_facecolor('indigo')
ax6.set_facecolor('violet')
fig

# %% [markdown]
# ### Identify each Axes with text

# %%
ax1.text(.4, .5, 'Axes 1')
ax2.text(.4, .5, 'Axes 2')
ax3.text(.4, .5, 'Axes 3')
ax4.text(.4, .5, 'Axes 4')
ax5.text(.4, .5, 'Axes 5')
ax6.text(.4, .5, 'Axes 6')

fig

# %% [markdown]
# ## Exercise
# Practice creating multiple Axes on a Figure and making adding objects to them.

# %%
# %matplotlib inline
import matplotlib.pyplot as plot
figEx,axes = plot.subplots(2,4,figsize=(6,6))
figEx.set_facecolor('red')
ax1 = axes[0,0]
ax2 = axes[0,1]
ax3  =axes[0,2]
ax4 = axes[0,3]
ax5 = axes[1,0]
ax6 = axes[1,1]
ax7 = axes[1,2]
ax8 = axes[1,3]
ax1.set_facecolor('yellow')
ax2.set_facecolor('pink')
ax3.set_facecolor('blue')
ax4.set_facecolor('violet')
ax5.set_facecolor('green')
ax6.set_facecolor('orange')
ax7.set_facecolor('yellow')
ax8.set_facecolor('cyan')

# %%
ax1.text(x=0.6,y=0.5,s='ax1')
ax2.text(x=0.6,y=0.5,s='ax2')
ax3.text(x=0.6,y=0.5,s='ax3')
ax4.text(x=0.6,y=0.5,s='ax4')
ax5.text(x=0.6,y=0.5,s='ax5')
ax6.text(x=0.6,y=0.5,s='ax6')
ax7.text(x=0.6,y=0.5,s='ax7')
ax8.text(x=0.6,y=0.5,s='ax8')
# Out:
# Text(0.6, 0.5, 'ax8')

# %%
figEx
