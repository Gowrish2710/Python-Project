# %% [markdown]
# # Boolean Selection Multiple Conditions
#
# ## Multiple condition expression
# So far, our boolean selections have involved a single condition. You can have as many conditions as you would like. To do so, you will need to combine your boolean expressions using the three logical operators, and, or, and not.
#
# ### Use `&`, `|` , `~`
# Although Python uses the keywords `and`, `or`, and `not`, these will not work with boolean Series. You must use the following operators instead.
#
# * `&` for and (ampersand character)
# * `|` for or (pipe character)
# * `~` for not (tilde character)
#
# ### Our first multiple condition expression
# Let's find all the rides longer than 1,000 seconds when it was cloudy. This query has two conditions - trip durations greater than 1,000 and cloudy weather. The way we approach the problem is to assign each condition to a separate variable. Since we desire both of the conditions to be true, we must use the and (`&`) operator.

# %%
import pandas as pd
bikes = pd.read_csv('../data/bikes.csv')
bikes.head(3)

# %% [markdown]
# Each single condition is placed on its own line before using the `&` operator to create the final filter that completes the boolean selection.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['events'] == 'cloudy'
filt = filt1 & filt2
bikes[filt].head(3)

# %% [markdown]
# ## Multiple conditions in one line
# It is possible to combine the entire expression into a single line. Many pandas users like doing this. Regardless, it is a good idea to know how it's done as you will definitely encounter it.
#
# ### Use parentheses to separate conditions
# You must encapsulate each condition in a set of parentheses in order to make this work. Each condition will be separated like this:
#
# ```
# (bikes['tripduration'] > 1000) & (bikes['events'] == 'cloudy')
# ```
#
# ### Same results
# The above expression is placed inside of *just the brackets* to get the same results. Again, I prefer assigning each condition to its own variable for better readability.

# %%
bikes[(bikes['tripduration'] > 1000) & (bikes['events'] == 'cloudy')].head(3)

# %% [markdown]
# ## Using an `or` condition
# Let's find all the rides that were done by females **or** had trip durations longer than 1,000 seconds. In this example, we need at least one of the conditions to be true, which necessitates the use of the or (`|`) operator.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Female'
filt = filt1 | filt2
bikes[filt].head(3)

# %% [markdown]
# ## Inverting a condition with the not operator
# The tilde character, `~`, represents the not operator and inverts a condition. For instance, if we wanted all the rides with trip duration less than or equal to 1000, we could do it like this:

# %%
filt = bikes['tripduration'] > 1000
bikes[~filt].head(3)

# %% [markdown]
# Of course, inverting single conditions is basically pointless as we can use the less than or equal to operator instead.

# %%
filt = bikes['tripduration'] <= 1000
bikes[filt].head(3)

# %% [markdown]
# ### Invert a more complex condition
# Typically, we will save the not operator for reversing more complex conditions. Let's reverse the condition for selecting rides by females or those with duration over 1,000 seconds. Logically, this should return only male riders with duration 1,000 or less.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Female'
filt = filt1 | filt2
bikes[~filt].head(3)

# %% [markdown]
# ### Even more complex conditions
# It is possible to build extremely complex conditions to select rows of your DataFrame that meet a very specific query. For instance, we can select males riders with trip duration between 1,000 and 2,000 seconds along with female riders with trip duration between 5,000 and 10,000 seconds. With multiple conditions, it's probably best to break out the logic into multiple steps:

# %%
filt1 = ((bikes['gender'] == 'Male') &
         (bikes['tripduration'] >= 1000) &
         (bikes['tripduration'] <= 2000))

filt2 = ((bikes['gender'] == 'Female') &
         (bikes['tripduration'] >= 5000) &
         (bikes['tripduration'] <= 10000))
filt = filt1 | filt2
bikes[filt].head(10)

# %% [markdown]
# ## Lots of equality conditions in a single column - use `isin`
# Occasionally, we will want to test equality in a single column with multiple values. This is most common in string columns. For instance, let's say we wanted to find all the rides where the events were either rain, snow, tstorms or sleet. One way to do this would be with four or conditions.

# %%
filt = ((bikes['events'] == 'rain') | 
        (bikes['events'] == 'snow') | 
        (bikes['events'] == 'tstorms') | 
        (bikes['events'] == 'sleet'))

bikes[filt].head(3)

# %% [markdown]
# Instead of using an operator, we will use the `isin` method. Pass it a list (or a set) of all the values you want to test equality with. The `isin` method will return a boolean Series and in this example, the same exact boolean Series as the previous one.

# %%
filt = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
bikes[filt].head(3)

# %% [markdown]
# ### Combining `isin` with other filters
# You can use the resulting boolean Series from the `isin` method in the same way as you would from the logical operators. For instance, If we wanted to find all the rides that had the same events as above and had a duration greater than 2,000 we would do the following:

# %%
filt1 = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
filt2 = bikes['tripduration'] > 2000
filt = filt1 & filt2
bikes[filt].head(3)

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# <span  style="color:green; font-size:16px">Select all movies from the 1970s.</span>

# %%
import pandas as ps
df = ps.read_csv('../data/movie.csv',index_col=0)
df[df['year'] >= 1970].head()
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# Avatar                                       178.0      James Cameron
# Pirates of the Caribbean: At World's End     169.0     Gore Verbinski
# Spectre                                      148.0         Sam Mendes
# The Dark Knight Rises                        164.0  Christopher Nolan
# John Carter                                  132.0     Andrew Stanton
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
# The Dark Knight Rises                         22000.0        Tom Hardy
# John Carter                                     475.0     Daryl Sabara
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
# The Dark Knight Rises                       27000.0    Christian Bale
# John Carter                                   640.0   Samantha Morton
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
# The Dark Knight Rises                       23000.0  ...   23000.0
# John Carter                                   632.0  ...     530.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
# The Dark Knight Rises                     448130642.0
# John Carter                                73058679.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
# The Dark Knight Rises                                     Action|Thriller
# John Carter                                       Action|Adventure|Sci-Fi
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
# The Dark Knight Rises                          813.0          1144337
# John Carter                                    462.0           212204
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                     deception|imprisonment|lawlessness|police offi...
# John Carter                               alien|american civil war|male nipple|mars|prin...
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
# The Dark Knight Rises                     English     USA  250000000.0
# John Carter                               English     USA  263700000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
# The Dark Knight Rises                            8.5
# John Carter                                      6.6
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select all movies from the 1970s that had IMDB scores greater than 8.</span>

# %%
filt = ((df['year'] >= 1970) & (df['imdb_score'] > 8))
df[filt].head()
# Out:
#                               year  color content_rating  duration  \
# title
# The Dark Knight Rises       2012.0  Color          PG-13     164.0
# The Avengers                2012.0  Color          PG-13     173.0
# Captain America: Civil War  2016.0  Color          PG-13     147.0
# Toy Story 3                 2010.0  Color              G     103.0
# WALL·E                      2008.0  Color              G      98.0
#
#                                 director_name  director_fb             actor1  \
# title
# The Dark Knight Rises       Christopher Nolan      22000.0          Tom Hardy
# The Avengers                      Joss Whedon          0.0    Chris Hemsworth
# Captain America: Civil War      Anthony Russo         94.0  Robert Downey Jr.
# Toy Story 3                       Lee Unkrich        125.0          Tom Hanks
# WALL·E                         Andrew Stanton        475.0  John Ratzenberger
#
#                             actor1_fb              actor2  actor2_fb  ...  \
# title                                                                 ...
# The Dark Knight Rises         27000.0      Christian Bale    23000.0  ...
# The Avengers                  26000.0   Robert Downey Jr.    21000.0  ...
# Captain America: Civil War    21000.0  Scarlett Johansson    19000.0  ...
# Toy Story 3                   15000.0   John Ratzenberger     1000.0  ...
# WALL·E                         1000.0        Fred Willard      729.0  ...
#
#                            actor3_fb        gross  \
# title
# The Dark Knight Rises        23000.0  448130642.0
# The Avengers                 19000.0  623279547.0
# Captain America: Civil War   11000.0  407197282.0
# Toy Story 3                    721.0  414984497.0
# WALL·E                         522.0  223806889.0
#
#                                                                genres  \
# title
# The Dark Knight Rises                                 Action|Thriller
# The Avengers                                  Action|Adventure|Sci-Fi
# Captain America: Civil War                    Action|Adventure|Sci-Fi
# Toy Story 3                 Adventure|Animation|Comedy|Family|Fantasy
# WALL·E                              Adventure|Animation|Family|Sci-Fi
#
#                            num_reviews  num_voted_users  \
# title
# The Dark Knight Rises            813.0          1144337
# The Avengers                     703.0           995415
# Captain America: Civil War       516.0           272670
# Toy Story 3                      453.0           544884
# WALL·E                           421.0           718837
#
#                                                                 plot_keywords  \
# title
# The Dark Knight Rises       deception|imprisonment|lawlessness|police offi...
# The Avengers                  alien invasion|assassin|battle|iron man|soldier
# Captain America: Civil War  based on comic book|knife|marvel cinematic uni...
# Toy Story 3                            college|day care|escape|teddy bear|toy
# WALL·E                                         earth|obesity|plant|robot|soil
#
#                            language country       budget  imdb_score
# title
# The Dark Knight Rises       English     USA  250000000.0         8.5
# The Avengers                English     USA  220000000.0         8.1
# Captain America: Civil War  English     USA  250000000.0         8.2
# Toy Story 3                 English     USA  200000000.0         8.3
# WALL·E                      English     USA  180000000.0         8.4
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">Select movies that were rated either R, PG-13, or PG.</span>

# %%
filt1 = df['content_rating'] == 'R'
filt2 = df['content_rating'] == 'PG-13'
filt3 = df['content_rating'] == 'PG'
filt = filt1 | filt2
filt = filt | filt3
df[filt].head()
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# Avatar                                       178.0      James Cameron
# Pirates of the Caribbean: At World's End     169.0     Gore Verbinski
# Spectre                                      148.0         Sam Mendes
# The Dark Knight Rises                        164.0  Christopher Nolan
# John Carter                                  132.0     Andrew Stanton
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
# The Dark Knight Rises                         22000.0        Tom Hardy
# John Carter                                     475.0     Daryl Sabara
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
# The Dark Knight Rises                       27000.0    Christian Bale
# John Carter                                   640.0   Samantha Morton
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
# The Dark Knight Rises                       23000.0  ...   23000.0
# John Carter                                   632.0  ...     530.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
# The Dark Knight Rises                     448130642.0
# John Carter                                73058679.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
# The Dark Knight Rises                                     Action|Thriller
# John Carter                                       Action|Adventure|Sci-Fi
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
# The Dark Knight Rises                          813.0          1144337
# John Carter                                    462.0           212204
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                     deception|imprisonment|lawlessness|police offi...
# John Carter                               alien|american civil war|male nipple|mars|prin...
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
# The Dark Knight Rises                     English     USA  250000000.0
# John Carter                               English     USA  263700000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
# The Dark Knight Rises                            8.5
# John Carter                                      6.6
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 4
# <span  style="color:green; font-size:16px">Select movies that are either rated PG-13 or were made after 2010.</span>

# %%
filt1 = ((df['content_rating'] == 'R') | (df['year'] > 2010))
df[filt1].head()
# Out:
#                                       year  color content_rating  duration  \
# title
# Spectre                             2015.0  Color          PG-13     148.0
# The Dark Knight Rises               2012.0  Color          PG-13     164.0
# John Carter                         2012.0  Color          PG-13     132.0
# Avengers: Age of Ultron             2015.0  Color          PG-13     141.0
# Batman v Superman: Dawn of Justice  2016.0  Color          PG-13     183.0
#
#                                         director_name  director_fb  \
# title
# Spectre                                    Sam Mendes          0.0
# The Dark Knight Rises               Christopher Nolan      22000.0
# John Carter                            Andrew Stanton        475.0
# Avengers: Age of Ultron                   Joss Whedon          0.0
# Batman v Superman: Dawn of Justice        Zack Snyder          0.0
#
#                                              actor1  actor1_fb  \
# title
# Spectre                             Christoph Waltz    11000.0
# The Dark Knight Rises                     Tom Hardy    27000.0
# John Carter                            Daryl Sabara      640.0
# Avengers: Age of Ultron             Chris Hemsworth    26000.0
# Batman v Superman: Dawn of Justice     Henry Cavill    15000.0
#
#                                                actor2  actor2_fb  ...  \
# title                                                             ...
# Spectre                                  Rory Kinnear      393.0  ...
# The Dark Knight Rises                  Christian Bale    23000.0  ...
# John Carter                           Samantha Morton      632.0  ...
# Avengers: Age of Ultron             Robert Downey Jr.    21000.0  ...
# Batman v Superman: Dawn of Justice       Lauren Cohan     4000.0  ...
#
#                                    actor3_fb        gross  \
# title
# Spectre                                161.0  200074175.0
# The Dark Knight Rises                23000.0  448130642.0
# John Carter                            530.0   73058679.0
# Avengers: Age of Ultron              19000.0  458991599.0
# Batman v Superman: Dawn of Justice    2000.0  330249062.0
#
#                                                        genres num_reviews  \
# title
# Spectre                             Action|Adventure|Thriller       602.0
# The Dark Knight Rises                         Action|Thriller       813.0
# John Carter                           Action|Adventure|Sci-Fi       462.0
# Avengers: Age of Ultron               Action|Adventure|Sci-Fi       635.0
# Batman v Superman: Dawn of Justice    Action|Adventure|Sci-Fi       673.0
#
#                                     num_voted_users  \
# title
# Spectre                                      275868
# The Dark Knight Rises                       1144337
# John Carter                                  212204
# Avengers: Age of Ultron                      462669
# Batman v Superman: Dawn of Justice           371639
#
#                                                                         plot_keywords  \
# title
# Spectre                                           bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises               deception|imprisonment|lawlessness|police offi...
# John Carter                         alien|american civil war|male nipple|mars|prin...
# Avengers: Age of Ultron             artificial intelligence|based on comic book|ca...
# Batman v Superman: Dawn of Justice  based on comic book|batman|sequel to a reboot|...
#
#                                    language country       budget  imdb_score
# title
# Spectre                             English      UK  245000000.0         6.8
# The Dark Knight Rises               English     USA  250000000.0         8.5
# John Carter                         English     USA  263700000.0         6.6
# Avengers: Age of Ultron             English     USA  250000000.0         7.5
# Batman v Superman: Dawn of Justice  English     USA  250000000.0         6.9
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 5
# <span  style="color:green; font-size:16px">Find all the movies that have at least one of the three actors with more than 10,000 Facebook likes.</span>

# %%
df['actor1'][df['num_voted_users'] > 10000].tail()
# Out:
# title
# Slacker            Tommy Pallotta
# Pink Flamingos             Divine
# Primer              Shane Carruth
# El Mariachi       Carlos Gallardo
# The Following         Natalie Zea
# Name: actor1, dtype: object

# %% [markdown]
# ### Exercise 6
# <span  style="color:green; font-size:16px">Reverse the condition from problem 4. In words, what have you selected?</span>

# %%
df[~filt].head()
# Out:
#                                               year  color content_rating  \
# title
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# Monsters University                         2013.0  Color              G
# Cars 2                                      2011.0  Color              G
# Toy Story 3                                 2010.0  Color              G
# WALL·E                                      2008.0  Color              G
#
#                                             duration   director_name  \
# title
# Star Wars: Episode VII - The Force Awakens       NaN     Doug Walker
# Monsters University                            104.0     Dan Scanlon
# Cars 2                                         106.0   John Lasseter
# Toy Story 3                                    103.0     Lee Unkrich
# WALL·E                                          98.0  Andrew Stanton
#
#                                             director_fb             actor1  \
# title
# Star Wars: Episode VII - The Force Awakens        131.0        Doug Walker
# Monsters University                                37.0      Steve Buscemi
# Cars 2                                            487.0       Joe Mantegna
# Toy Story 3                                       125.0          Tom Hanks
# WALL·E                                            475.0  John Ratzenberger
#
#                                             actor1_fb              actor2  \
# title
# Star Wars: Episode VII - The Force Awakens      131.0          Rob Walker
# Monsters University                           12000.0        Tyler Labine
# Cars 2                                         1000.0  Thomas Kretschmann
# Toy Story 3                                   15000.0   John Ratzenberger
# WALL·E                                         1000.0        Fred Willard
#
#                                             actor2_fb  ... actor3_fb  \
# title                                                  ...
# Star Wars: Episode VII - The Force Awakens       12.0  ...       NaN
# Monsters University                             779.0  ...     760.0
# Cars 2                                          919.0  ...     776.0
# Toy Story 3                                    1000.0  ...     721.0
# WALL·E                                          729.0  ...     522.0
#
#                                                   gross  \
# title
# Star Wars: Episode VII - The Force Awakens          NaN
# Monsters University                         268488329.0
# Cars 2                                      191450875.0
# Toy Story 3                                 414984497.0
# WALL·E                                      223806889.0
#
#                                                                                genres  \
# title
# Star Wars: Episode VII - The Force Awakens                                Documentary
# Monsters University                         Adventure|Animation|Comedy|Family|Fantasy
# Cars 2                                        Adventure|Animation|Comedy|Family|Sport
# Toy Story 3                                 Adventure|Animation|Comedy|Family|Fantasy
# WALL·E                                              Adventure|Animation|Family|Sci-Fi
#
#                                            num_reviews  num_voted_users  \
# title
# Star Wars: Episode VII - The Force Awakens         NaN                8
# Monsters University                              376.0           235025
# Cars 2                                           304.0           101178
# Toy Story 3                                      453.0           544884
# WALL·E                                           421.0           718837
#
#                                                                                 plot_keywords  \
# title
# Star Wars: Episode VII - The Force Awakens                                                NaN
# Monsters University                         cheating|fraternity|monster|singing in a car|u...
# Cars 2                                         best friend|car race|conspiracy|gadget car|spy
# Toy Story 3                                            college|day care|escape|teddy bear|toy
# WALL·E                                                         earth|obesity|plant|robot|soil
#
#                                            language country       budget  \
# title
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
# Monsters University                         English     USA  200000000.0
# Cars 2                                      English     USA  200000000.0
# Toy Story 3                                 English     USA  200000000.0
# WALL·E                                      English     USA  180000000.0
#
#                                             imdb_score
# title
# Star Wars: Episode VII - The Force Awakens         7.1
# Monsters University                                7.3
# Cars 2                                             6.3
# Toy Story 3                                        8.3
# WALL·E                                             8.4
#
# [5 rows x 21 columns]
